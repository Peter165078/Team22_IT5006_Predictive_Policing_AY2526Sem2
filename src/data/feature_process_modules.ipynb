# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

pd.set_option("display.max_columns", None)

def get_project_root() -> Path:
    current = Path(__file__).resolve() if "__file__" in globals() else Path().resolve()

    for parent in [current] + list(current.parents):
        if (parent / ".git").exists():
            return parent

    raise RuntimeError("Project root not found. Ensure you're inside a Git project.")

# ---- Core paths ----
PROJECT_ROOT = get_project_root()

DATA_PATH = PROJECT_ROOT / "data" / "raw"
OUTPUT_DIR = PROJECT_ROOT / "artifacts" / "figures"

# Ensure output directory exists
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# %%
df = pd.read_csv(f"{DATA_PATH}/Crimes_-_2001_to_Present_20260216.csv")
df.shape
# Out:
# (8495400, 22)

# %%
# 直接从原始字符串的年份部分筛选，不改变任何格式
# 原始格式: "01/15/2016 11:00:00 PM" -> 年份在 index 6:10
mask = df["Date"].str[6:10].isin([str(y) for y in range(2026, 2027)])
df_filtered = df.loc[mask].copy()

print(f"筛选前: {df.shape}")
print(f"筛选后: {df_filtered.shape}")
print(f"年份分布:\n{df['Date'].str[6:10].value_counts().sort_index()}")

# 保存，保持原始格式
output_path = f"{DATA_PATH}/Crimes_2023_to_2025.csv"
df_filtered.to_csv(output_path, index=False)
print(f"\n已保存至: {output_path}")
# Out:
# 筛选前: (8495400, 22)
# 筛选后: (19660, 22)
# 年份分布:
# Date
# 2001    485958
# 2002    486831
# 2003    475999
# 2004    469443
# 2005    453788
# 2006    448198
# 2007    437108
# 2008    427216
# 2009    392866
# 2010    370564
# 2011    352052
# 2012    336373
# 2013    307610
# 2014    275882
# 2015    264887
# 2016    269957
# 2017    269283
# 2018    269143
# 2019    261699
# 2020    212695
# 2021    209644
# 2022    239987
# 2023    263266
# 2024    258969
# 2025    236322
# 2026     19660
# Name: count, dtype: int64
#
# 已保存至: /home/myCourse/it5006/Team22_IT5006_Predictive_Policing_AY2526Sem2/data/raw/Crimes_2023_to_2025.csv
